# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
data = load_iris()

X,y = data.data, data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)#20% testing,80%training

# %%
len(X_train)
# Out:
# 120

# %%
import numpy as np
import matplotlib.pyplot as plt

counts = np.bincount(y_train)
positions = np.arange(3)

plt.bar(position, counts)
plt.xticks(positions, data.target_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       4 counts = np.bincount(y_train)
#       5 positions = np.arange(3)
# ----> 7 plt.bar(position, counts)
#       8 plt.xticks(positions, data.target_names)
#
# NameError: name 'position' is not defined
